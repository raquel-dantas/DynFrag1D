# %%
import numpy as np

import DFProcessResults
import DFPlotResults

# %%
#  Path to the output files
filepath_10to3 = "output_mesh_study/10to3/"
bar_length = 50e-3

# %%
# 10to3: CZM 625 elements Uniform mesh
simulation_name = "CZM 625 elements"
n_elements = 625
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_625/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm625 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_czm625 = [simulation_name, time, n_fragments]
energy_diss_uniform_czm625 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to4 CZM 625 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_625_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to4 CZM 625 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_625_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to4 CZM 625 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_625_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 1250 elements Uniform mesh
simulation_name = "CZM 1250 elements"
n_elements = 1250
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_1250/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm1250 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_czm1250 = [simulation_name, time, n_fragments]
energy_diss_uniform_czm1250 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to4 CZM 1250 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_1250_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to4 CZM 1250 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_1250_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to4 CZM 1250 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_1250_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 2500 elements Uniform mesh
simulation_name = "CZM 2500 elements"
n_elements = 2500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_2500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm2500 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_czm2500 = [simulation_name, time, n_fragments]
energy_diss_uniform_czm2500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to4 CZM 2500 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_2500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to4 CZM 2500 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_2500_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to4 CZM 2500 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_2500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 5000 elements Uniform mesh
simulation_name = "CZM 5000 elements"
n_elements = 5000
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_5000/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm5000 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_czm5000 = [simulation_name, time, n_fragments]
energy_diss_uniform_czm5000 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to4 CZM 5000 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_5000_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to4 CZM 5000 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_5000_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to4 CZM 5000 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_5000_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 7500 elements Uniform mesh
simulation_name = "CZM 7500 elements"
n_elements = 7500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_7500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm7500 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_czm7500 = [simulation_name, time, n_fragments]
energy_diss_uniform_czm7500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to4 CZM 7500 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_7500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to4 CZM 7500 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_7500_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to4 CZM 7500 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to4_czm_uniform_7500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Initialize what you want to compare:

avg_stress_10to3_uniform_mesh = []
n_fragments_10to3_uniform_mesh  = []
energy_diss_10to3_uniform_mesh = []

avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_czm625)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_czm1250)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_czm2500)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_czm5000)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_czm7500)

n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_czm625)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_czm1250)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_czm2500)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_czm5000)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_czm7500)

energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_czm625)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_czm1250)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_czm2500)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_czm5000)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_czm7500)

# %%
DFPlotResults.plotResultsComparison(
    avg_stress_10to3_uniform_mesh,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM uniform: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_uniform_comp_avgstress"
)
DFPlotResults.plotResultsComparison(
    n_fragments_10to3_uniform_mesh,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_uniform_comp_nfrag"
)
meshes = [625, 1250, 2500, 5000, 7500]

DFPlotResults.plotConvergence(
    energy_diss_10to3_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="Dissipated Energy ($ J/ {m^2} $)",
    plot_title="10to3 CZM uniform: Dissipated energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_convergence_uniform_ediss"
)

DFPlotResults.plotConvergence(
    n_fragments_10to3_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="N",
    plot_title="10to3 CZM uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_convergence_uniform_nfrag"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 625 elements non-niform mesh
simulation_name = "CZM 625 elements"
n_elements = 625
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_625/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm625 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_czm625 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_czm625 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM 625 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_625_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM 625 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_625_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to3 CZM 625 non-uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_625_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 1250 elements non-niform mesh
simulation_name = "CZM 1250 elements"
n_elements = 1250
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_1250/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm1250 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_czm1250 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_czm1250 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM 1250 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_1250_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM 1250 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_1250_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to3 CZM 1250 non-uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_1250_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 2500 elements non-uniform mesh
simulation_name = "CZM 2500 elements"
n_elements = 2500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_2500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm2500 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_czm2500 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_czm2500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM 2500 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_2500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM 2500 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_2500_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to3 CZM 2500 non-uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_2500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 5000 elements non-niform mesh
simulation_name = "CZM 5000 elements"
n_elements = 5000
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_5000/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm5000 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_czm5000 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_czm5000 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM 5000 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_5000_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM 5000 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_5000_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to3 CZM 5000 non-uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_5000_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: CZM 7500 elements non-niform mesh
simulation_name = "CZM 7500 elements"
n_elements = 7500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_7500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm7500 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_czm7500 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_czm7500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM 7500 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_625_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM 7500 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_7500_nfrag"
)

DFPlotResults.plotVarEnergiesCZM(
    var_energies,
    time,
    plot_title="10to3 CZM 7500 uniform elements: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_625_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Initialize what you want to compare:

avg_stress_10to3_non_uniform_mesh = []
n_fragments_10to3_non_uniform_mesh  = []
energy_diss_10to3_non_uniform_mesh = []

avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_czm625)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_czm1250)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_czm2500)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_czm5000)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_czm7500)

n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_czm625)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_czm1250)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_czm2500)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_czm5000)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_czm7500)

energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_czm625)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_czm1250)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_czm2500)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_czm5000)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_czm7500)


DFPlotResults.plotResultsComparison(
    avg_stress_10to3_non_uniform_mesh,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 CZM non-uniform: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_comp_avgstress"
)
DFPlotResults.plotResultsComparison(
    n_fragments_10to3_non_uniform_mesh,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 CZM non-uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_non_uniform_comp_nfrag"
)
meshes = [625, 1250, 2500, 5000, 7500]

DFPlotResults.plotConvergence(
    energy_diss_10to3_non_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="Dissipated Energy ($ J/ {m^2} $)",
    plot_title="10to3 CZM non-uniform: Dissipated energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_convergence_non_uniform_ediss"
)

DFPlotResults.plotConvergence(
    n_fragments_10to3_non_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="N",
    plot_title="10to3 CZM non-uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_czm_convergence_non_uniform_nfrag"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
