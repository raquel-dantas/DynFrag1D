# %%
import numpy as np

import DFProcessResults
import DFPlotResults

# %%
#  Path to the output files
filepath_10to3 = "output_mesh_study/10to3/"

# %%
# 10to3: Lip-field 625 elements Uniform mesh
simulation_name = "LIP 625 elements"
n_elements = 625
file_address = filepath_10to3 + "10to3_lipfield_uniform_625/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip625 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_lip625 = [simulation_name, time, n_fragments]
energy_diss_uniform_lip625 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 625 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_625_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 625 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_625_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 625 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_625_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 1250 elements Uniform mesh
simulation_name = "LIP 1250 elements"
n_elements = 1250
file_address = filepath_10to3 + "10to3_lipfield_uniform_1250/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip1250 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_lip1250 = [simulation_name, time, n_fragments]
energy_diss_uniform_lip1250 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 1250 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_1250_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 1250 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_1250_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 1250 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_1250_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 2500 elements Uniform mesh
simulation_name = "LIP 2500 elements"
n_elements = 2500
file_address = filepath_10to3 + "10to3_lipfield_uniform_2500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip2500 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_lip2500 = [simulation_name, time, n_fragments]
energy_diss_uniform_lip2500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 2500 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_2500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 2500 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_2500_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 2500 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_2500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 5000 elements Uniform mesh
simulation_name = "LIP 5000 elements"
n_elements = 5000
file_address = filepath_10to3 + "10to3_lipfield_uniform_5000/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip5000 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_lip5000 = [simulation_name, time, n_fragments]
energy_diss_uniform_lip5000 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 5000 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_5000_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 5000 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_5000_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 5000 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_5000_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 7500 elements Uniform mesh
simulation_name = "LIP 7500 elements"
n_elements = 7500
file_address = filepath_10to3 + "10to3_lipfield_uniform_7500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip7500 = [simulation_name, time, avg_stress_bar]
n_fragments_uniform_lip7500 = [simulation_name, time, n_fragments]
energy_diss_uniform_lip7500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 7500 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_7500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 7500 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_7500_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 7500 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_7500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Initialize what you want to compare:

avg_stress_10to3_uniform_mesh = []
n_fragments_10to3_uniform_mesh  = []
energy_diss_10to3_uniform_mesh = []

avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_lip625)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_lip1250)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_lip2500)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_lip5000)
avg_stress_10to3_uniform_mesh.append(avg_stress_uniform_lip7500)

n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_lip625)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_lip1250)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_lip2500)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_lip5000)
n_fragments_10to3_uniform_mesh.append(n_fragments_uniform_lip7500)

energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_lip625)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_lip1250)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_lip2500)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_lip5000)
energy_diss_10to3_uniform_mesh.append(energy_diss_uniform_lip7500)

# %%
DFPlotResults.plotResultsComparison(
    avg_stress_10to3_uniform_mesh,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP uniform: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_comp_avgstress"
)
DFPlotResults.plotResultsComparison(
    n_fragments_10to3_uniform_mesh,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_uniform_comp_nfrag"
)
meshes = [625, 1250, 2500, 5000, 7500]

DFPlotResults.plotConvergence(
    energy_diss_10to3_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="Dissipated Energy ($ J/ {m^2} $)",
    plot_title="10to3 LIP uniform: Dissipated energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_convergence_uniform_ediss"
)

DFPlotResults.plotConvergence(
    n_fragments_10to3_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="N",
    plot_title="10to3 LIP uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_convergence_uniform_nfrag"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 625 elements non-niform mesh
simulation_name = "LIP 625 elements"
n_elements = 625
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_625/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip625 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_lip625 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_lip625 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 625 uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_625_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 625 uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_625_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 625 uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_625_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 1250 elements non-uniform mesh
simulation_name = "LIP 1250 elements"
n_elements = 1250
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_1250/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip1250 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_lip1250 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_lip1250 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 1250 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_1250_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 1250 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_1250_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 1250 non-uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_1250_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 2500 elements non-uniform mesh
simulation_name = "LIP 2500 elements"
n_elements = 2500
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_2500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip2500 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_lip2500 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_lip2500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 2500 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_2500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 2500 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_2500_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 2500 non-uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_2500_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 5000 elements non-uniform mesh
simulation_name = "LIP 5000 elements"
n_elements = 5000
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_5000/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip5000 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_lip5000 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_lip5000 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 5000 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_5000_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 5000 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_5000_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 5000 non-uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_5000_energy"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 10to3: Lip-field 7500 elements non-uniform mesh
simulation_name = "LIP 7500 elements"
n_elements = 7500
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_7500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip7500 = [simulation_name, time, avg_stress_bar]
n_fragments_non_uniform_lip7500 = [simulation_name, time, n_fragments]
energy_diss_non_uniform_lip7500 = [simulation_name, n_elements, energy_diss]

# %%
DFPlotResults.plotResults(
    avg_stress_bar * 1e-6,
    time,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP 7500 non-uniform elements: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_7500_avgstress"
)
DFPlotResults.plotResults(
    n_fragments,
    time,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP 7500 non-uniform elements: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_7500_nfrag"
)

DFPlotResults.plotVarEnergiesLipfield(
    var_energies,
    time,
    plot_title="10to3 7500 non-uniform elements LIP: Variation of energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_7500_energy"
)

# %%
# Initialize what you want to compare:

avg_stress_10to3_non_uniform_mesh = []
n_fragments_10to3_non_uniform_mesh  = []
energy_diss_10to3_non_uniform_mesh = []

avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_lip625)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_lip1250)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_lip2500)
avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_lip5000)
# avg_stress_10to3_non_uniform_mesh.append(avg_stress_non_uniform_lip7500)

n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_lip625)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_lip1250)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_lip2500)
n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_lip5000)
# n_fragments_10to3_non_uniform_mesh.append(n_fragments_non_uniform_lip7500)

energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_lip625)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_lip1250)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_lip2500)
energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_lip5000)
# energy_diss_10to3_non_uniform_mesh.append(energy_diss_non_uniform_lip7500)

# %%
DFPlotResults.plotResultsComparison(
    avg_stress_10to3_non_uniform_mesh,
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    plot_title="10to3 LIP non-uniform: Average stress at the bar",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_comp_avgstress"
)
DFPlotResults.plotResultsComparison(
    n_fragments_10to3_non_uniform_mesh,
    label_x="time (s)",
    label_y="N",
    plot_title="10to3 LIP non-uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_non_uniform_comp_nfrag"
)
meshes = [625, 1250, 2500, 5000, 7500]

DFPlotResults.plotConvergence(
    energy_diss_10to3_non_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="Dissipated Energy ($ J/ {m^2} $)",
    plot_title="10to3 LIP non-uniform: Dissipated energy",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_convergence_non_uniform_ediss"
)

DFPlotResults.plotConvergence(
    n_fragments_10to3_non_uniform_mesh,
    meshes,
    label_x="Number of elements",
    label_y="N",
    plot_title="10to3 LIP non-uniform: Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lipfield_convergence_non_uniform_nfrag"
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
