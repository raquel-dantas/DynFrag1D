# %%
import numpy as np

import DFProcessResults
import DFPlotResults

# %%
#  Path to the output files
filepath_10to3 = "output_mesh_study/10to3/"
bar_length = 50e-3

# %%
# 10to3: CZM 625 elements Uniform mesh
simulation_name = "CZM 625 elements"
n_elements = 625
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_625/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_uniform_czm625 = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm625 = [simulation_name, time_uniform_czm625, avg_stress_bar]
n_fragments_uniform_czm625 = [simulation_name, time_uniform_czm625, n_fragments]
energy_diss_uniform_czm625 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 1250 elements Uniform mesh
simulation_name = "CZM 1250 elements"
n_elements = 1250
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_1250/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_uniform_czm1250 = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm1250 = [simulation_name, time_uniform_czm1250, avg_stress_bar]
n_fragments_uniform_czm1250 = [simulation_name, time_uniform_czm1250, n_fragments]
energy_diss_uniform_czm1250 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 2500 elements Uniform mesh
simulation_name = "CZM 2500 elements"
n_elements = 2500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_2500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_uniform_czm2500 = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm2500 = [simulation_name, time_uniform_czm2500, avg_stress_bar]
n_fragments_uniform_czm2500 = [simulation_name, time_uniform_czm2500, n_fragments]
energy_diss_uniform_czm2500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 5000 elements Uniform mesh
simulation_name = "CZM 5000 elements"
n_elements = 5000
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_5000/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_uniform_czm5000 = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm5000 = [simulation_name, time_uniform_czm5000, avg_stress_bar]
n_fragments_uniform_czm5000 = [simulation_name, time_uniform_czm5000, n_fragments]
energy_diss_uniform_czm5000 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 7500 elements Uniform mesh
simulation_name = "CZM 7500 elements"
n_elements = 7500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_uniform_7500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_uniform_czm7500 = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_czm7500 = [simulation_name, time_uniform_czm7500, avg_stress_bar]
n_fragments_uniform_czm7500 = [simulation_name, time_uniform_czm7500, n_fragments]
energy_diss_uniform_czm7500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 625 elements non-uniform mesh
simulation_name = "CZM 625 elements"
n_elements = 625
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_625/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_non_uniform_czm625 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm625 = [simulation_name, time_non_uniform_czm625, avg_stress_bar]
n_fragments_non_uniform_czm625 = [simulation_name, time_non_uniform_czm625, n_fragments]
energy_diss_non_uniform_czm625 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 1250 elements non-uniform mesh
simulation_name = "CZM 1250 elements"
n_elements = 1250
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_1250/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_non_uniform_czm1250 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm1250 = [simulation_name, time_non_uniform_czm1250, avg_stress_bar]
n_fragments_non_uniform_czm1250 = [simulation_name, time_non_uniform_czm1250, n_fragments]
energy_diss_non_uniform_czm1250 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 2500 elements non-uniform mesh
simulation_name = "CZM 2500 elements"
n_elements = 2500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_2500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 )
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_non_uniform_czm2500 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm2500 = [simulation_name, time_non_uniform_czm2500, avg_stress_bar]
n_fragments_non_uniform_czm2500 = [simulation_name, time_non_uniform_czm2500, n_fragments]
energy_diss_non_uniform_czm2500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 5000 elements non-uniform mesh
simulation_name = "CZM 5000 elements"
n_elements = 5000
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_5000/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_non_uniform_czm5000 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm5000 = [simulation_name, time_non_uniform_czm5000, avg_stress_bar]
n_fragments_non_uniform_czm5000 = [simulation_name, time_non_uniform_czm5000, n_fragments]
energy_diss_non_uniform_czm5000 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: CZM 7500 elements non-uniform mesh
simulation_name = "CZM 7500 elements"
n_elements = 7500
h = bar_length / n_elements
file_address = filepath_10to3 + "10to3_akantu_non_uniform_7500/akantu_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 20 )
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllStepsCZM_dumptype2(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3 / h  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesCZM(energies, n_files, n_elements)
time_non_uniform_czm7500 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_czm7500 = [simulation_name, time_non_uniform_czm7500, avg_stress_bar]
n_fragments_non_uniform_czm7500 = [simulation_name, time_non_uniform_czm7500, n_fragments]
energy_diss_non_uniform_czm7500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 625 elements Uniform mesh
simulation_name = "LIP 625 elements"
n_elements = 625
file_address = filepath_10to3 + "10to3_lipfield_uniform_625/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_uniform_lip625  = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip625 = [simulation_name, time_uniform_lip625 , avg_stress_bar]
n_fragments_uniform_lip625 = [simulation_name, time_uniform_lip625 , n_fragments]
energy_diss_uniform_lip625 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 1250 elements Uniform mesh
simulation_name = "LIP 1250 elements"
n_elements = 1250
file_address = filepath_10to3 + "10to3_lipfield_uniform_1250/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_uniform_lip1250  = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip1250 = [simulation_name, time_uniform_lip1250 , avg_stress_bar]
n_fragments_uniform_lip1250 = [simulation_name, time_uniform_lip1250 , n_fragments]
energy_diss_uniform_lip1250 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 2500 elements Uniform mesh
simulation_name = "LIP 2500 elements"
n_elements = 2500
file_address = filepath_10to3 + "10to3_lipfield_uniform_2500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_uniform_lip2500  = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip2500 = [simulation_name, time_uniform_lip2500 , avg_stress_bar]
n_fragments_uniform_lip2500 = [simulation_name, time_uniform_lip2500 , n_fragments]
energy_diss_uniform_lip2500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 5000 elements Uniform mesh
simulation_name = "LIP 5000 elements"
n_elements = 5000
file_address = filepath_10to3 + "10to3_lipfield_uniform_5000/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_uniform_lip5000  = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip5000 = [simulation_name, time_uniform_lip5000 , avg_stress_bar]
n_fragments_uniform_lip5000 = [simulation_name, time_uniform_lip5000 , n_fragments]
energy_diss_uniform_lip5000 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 7500 elements Uniform mesh
simulation_name = "LIP 7500 elements"
n_elements = 7500
file_address = filepath_10to3 + "10to3_lipfield_uniform_7500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_uniform_lip7500  = np.linspace(0, time_simulation, n_files)


avg_stress_uniform_lip7500 = [simulation_name, time_uniform_lip7500 , avg_stress_bar]
n_fragments_uniform_lip7500 = [simulation_name, time_uniform_lip7500 , n_fragments]
energy_diss_uniform_lip7500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 625 elements non-uniform mesh
simulation_name = "LIP 625 elements"
n_elements = 625
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_625/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_non_uniform_lip625 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip625 = [simulation_name, time_non_uniform_lip625, avg_stress_bar]
n_fragments_non_uniform_lip625 = [simulation_name, time_non_uniform_lip625, n_fragments]
energy_diss_non_uniform_lip625 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 1250 elements non-uniform mesh
simulation_name = "LIP 1250 elements"
n_elements = 1250
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_1250/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_non_uniform_lip1250 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip1250 = [simulation_name, time_non_uniform_lip1250, avg_stress_bar]
n_fragments_non_uniform_lip1250 = [simulation_name, time_non_uniform_lip1250, n_fragments]
energy_diss_non_uniform_lip1250 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 2500 elements non-uniform mesh
simulation_name = "LIP 2500 elements"
n_elements = 2500
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_2500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_non_uniform_lip2500 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip2500 = [simulation_name, time_non_uniform_lip2500, avg_stress_bar]
n_fragments_non_uniform_lip2500 = [simulation_name, time_non_uniform_lip2500, n_fragments]
energy_diss_non_uniform_lip2500 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 5000 elements non-uniform mesh
simulation_name = "LIP 5000 elements"
n_elements = 5000
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_5000/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 + 1)
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_non_uniform_lip5000 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip5000 = [simulation_name, time_non_uniform_lip5000, avg_stress_bar]
n_fragments_non_uniform_lip5000 = [simulation_name, time_non_uniform_lip5000, n_fragments]
energy_diss_non_uniform_lip5000 = [simulation_name, n_elements, energy_diss]

# %%
# 10to3: Lip-field 7500 elements non-uniform mesh
simulation_name = "LIP 7500 elements"
n_elements = 7500
file_address = filepath_10to3 + "10to3_lipfield_non_uniform_7500/lipfield_"
time_data = DFProcessResults.getTimeData(file_address)
time_simulation = time_data[0]
dt = time_data[1]
n_steps = time_data[2]
n_files = int(n_steps / 10 )
avg_stress_bar, energies, n_fragments = DFProcessResults.getResultsAllSteps(file_address, n_files, n_steps)
energy_diss = DFProcessResults.getDissipatedEnergy(energies, n_files) * 1e-3  # from J to KJ
var_energies = DFProcessResults.computeVarEnergiesLipfield(energies, n_files)
time_non_uniform_lip7500 = np.linspace(0, time_simulation, n_files)


avg_stress_non_uniform_lip7500 = [simulation_name, time_non_uniform_lip7500, avg_stress_bar]
n_fragments_non_uniform_lip7500 = [simulation_name, time_non_uniform_lip7500, n_fragments]
energy_diss_non_uniform_lip7500 = [simulation_name, n_elements, energy_diss]

# %%
stress_limit = 300e6
young_modulus = 275e9
strain_rate = 1e3
time_peakstress = stress_limit / (young_modulus * strain_rate)  # Time peak stress
nstep_peak = int(time_peakstress / dt)


from matplotlib import pyplot as plt
def plotCompareStressCZMLIP(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()

def plotCompareNfragCZMLIP(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()

# %%
# 625 elements

stress_bar = [
    ["LIP: 625el Uniform", time_uniform_lip625, avg_stress_uniform_lip625[2]/10**6],
    ["LIP: 625el Non-Uniform", time_non_uniform_lip625, avg_stress_non_uniform_lip625[2]/10**6],
    ["CZM: 625el Uniform", time_uniform_czm625, avg_stress_uniform_czm625[2]/10**6],
    ["CZM: 625el Non-Uniform", time_non_uniform_czm625, avg_stress_non_uniform_czm625[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 625 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_625_avg_stress",
)

nfrag = [
    ["LIP: 625el Uniform", time_uniform_lip625, n_fragments_uniform_lip625[2]],
    ["LIP: 625el Non-Uniform", time_non_uniform_lip625, n_fragments_non_uniform_lip625[2]],
    ["CZM: 625el Uniform", time_uniform_czm625, n_fragments_uniform_czm625[2]],
    ["CZM: 625el Non-Uniform", time_non_uniform_czm625, n_fragments_non_uniform_czm625[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 625 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_625_nfrag",
)


# 1250 elements

stress_bar = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, avg_stress_uniform_lip1250[2]/10**6],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, avg_stress_non_uniform_lip1250[2]/10**6],
    ["CZM: 1250el Uniform", time_uniform_czm1250, avg_stress_uniform_czm1250[2]/10**6],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, avg_stress_non_uniform_czm1250[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 1250 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_avg_stress",
)

nfrag = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, n_fragments_uniform_lip1250[2]],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, n_fragments_non_uniform_lip1250[2]],
    ["CZM: 1250el Uniform", time_uniform_czm1250, n_fragments_uniform_czm1250[2]],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, n_fragments_non_uniform_czm1250[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 1250 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_nfrag",
)


# 2500 elements

stress_bar = [
    ["LIP: 2500el Uniform", time_uniform_lip2500, avg_stress_uniform_lip2500[2]/10**6],
    ["LIP: 2500el Non-Uniform", time_non_uniform_lip2500, avg_stress_non_uniform_lip2500[2]/10**6],
    ["CZM: 2500el Uniform", time_uniform_czm2500, avg_stress_uniform_czm2500[2]/10**6],
    ["CZM: 2500el Non-Uniform", time_non_uniform_czm2500, avg_stress_non_uniform_czm2500[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 2500 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_2500_avg_stress",
)

nfrag = [
    ["LIP: 2500el Uniform", time_uniform_lip2500, n_fragments_uniform_lip2500[2]],
    ["LIP: 2500el Non-Uniform", time_non_uniform_lip2500, n_fragments_non_uniform_lip2500[2]],
    ["CZM: 2500el Uniform", time_uniform_czm2500, n_fragments_uniform_czm2500[2]],
    ["CZM: 2500el Non-Uniform", time_non_uniform_czm2500, n_fragments_non_uniform_czm2500[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 2500 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_2500_nfrag",
)


# 5000 elements

stress_bar = [
    ["LIP: 5000el Uniform", time_uniform_lip5000, avg_stress_uniform_lip5000[2]/10**6],
    ["LIP: 5000el Non-Uniform", time_non_uniform_lip5000, avg_stress_non_uniform_lip5000[2]/10**6],
    ["CZM: 5000el Uniform", time_uniform_czm5000, avg_stress_uniform_czm5000[2]/10**6],
    ["CZM: 5000el Non-Uniform", time_non_uniform_czm5000, avg_stress_non_uniform_czm5000[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 5000 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_5000_avg_stress",
)

nfrag = [
    ["LIP: 5000el Uniform", time_uniform_lip5000, n_fragments_uniform_lip5000[2]],
    ["LIP: 5000el Non-Uniform", time_non_uniform_lip5000, n_fragments_non_uniform_lip5000[2]],
    ["CZM: 5000el Uniform", time_uniform_czm5000, n_fragments_uniform_czm5000[2]],
    ["CZM: 5000el Non-Uniform", time_non_uniform_czm5000, n_fragments_non_uniform_czm5000[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 5000 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_5000_nfrag",
)

# 7500 elements

stress_bar = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, avg_stress_uniform_lip7500[2]/10**6],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, avg_stress_non_uniform_lip7500[2]/10**6],
    ["CZM: 7500el Uniform", time_uniform_czm7500, avg_stress_uniform_czm7500[2]/10**6],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, avg_stress_non_uniform_czm7500[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 7500 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_avg_stress",
)

nfrag = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, n_fragments_uniform_lip7500[2]],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, n_fragments_non_uniform_lip7500[2]],
    ["CZM: 7500el Uniform", time_uniform_czm7500, n_fragments_uniform_czm7500[2]],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, n_fragments_non_uniform_czm7500[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 7500 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_nfrag",
)

# %%
# 1250 elements

stress_bar = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, avg_stress_uniform_lip1250[2]/10**6],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, avg_stress_non_uniform_lip1250[2]/10**6],
    ["CZM: 1250el Uniform", time_uniform_czm1250, avg_stress_uniform_czm1250[2]/10**6],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, avg_stress_non_uniform_czm1250[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 1250 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_avg_stress",
)

nfrag = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, n_fragments_uniform_lip1250[2]],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, n_fragments_non_uniform_lip1250[2]],
    ["CZM: 1250el Uniform", time_uniform_czm1250, n_fragments_uniform_czm1250[2]],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, n_fragments_non_uniform_czm1250[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 1250 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_nfrag",
)

# %%
# 7500 elements

stress_bar = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, avg_stress_uniform_lip7500[2]/10**6],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, avg_stress_non_uniform_lip7500[2]/10**6],
    ["CZM: 7500el Uniform", time_uniform_czm7500, avg_stress_uniform_czm7500[2]/10**6],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, avg_stress_non_uniform_czm7500[2]/10**6],
]


plotCompareStressCZMLIP(
    stress_bar,
    title="10to3 7500 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_avg_stress",
)

nfrag = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, n_fragments_uniform_lip7500[2]],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, n_fragments_non_uniform_lip7500[2]],
    ["CZM: 7500el Uniform", time_uniform_czm7500, n_fragments_uniform_czm7500[2]],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, n_fragments_non_uniform_czm7500[2]],
]


plotCompareNfragCZMLIP(
    nfrag,
    title="10to3 7500 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_nfrag",
)

# %%
def plotCompareStressCZMLIP_limitime(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()


def plotCompareNfragCZMLIP_limitime(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.xlim([0, 2.5e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()


stress_bar = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, avg_stress_uniform_lip7500[2]/10**6],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, avg_stress_non_uniform_lip7500[2]/10**6],
    ["CZM: 7500el Uniform", time_uniform_czm7500, avg_stress_uniform_czm7500[2]/10**6],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, avg_stress_non_uniform_czm7500[2]/10**6],
]


plotCompareStressCZMLIP_limitime(
    stress_bar,
    title="10to3 7500 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_avg_stress",
)

nfrag = [
    ["LIP: 7500el Uniform", time_uniform_lip7500, n_fragments_uniform_lip7500[2]],
    ["LIP: 7500el Non-Uniform", time_non_uniform_lip7500, n_fragments_non_uniform_lip7500[2]],
    ["CZM: 7500el Uniform", time_uniform_czm7500, n_fragments_uniform_czm7500[2]],
    ["CZM: 7500el Non-Uniform", time_non_uniform_czm7500, n_fragments_non_uniform_czm7500[2]],
]


plotCompareNfragCZMLIP_limitime(
    nfrag,
    title="10to3 7500 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_7500_nfrag",
)

# %%
def plotCompareStressCZMLIP_limitime(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 0.98 * stress_limit* 1e-6]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()


def plotCompareNfragCZMLIP_limitime(results, title:str, label_x:str, label_y:str, save_plot: bool, save_filename: str):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    # plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)
    plt.rcParams.update({'font.size': 12})


    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue')
    name_simulation = results[0][0]
    x_values = results[0][1] + 0.98 * time_peakstress
    y_values = results[0][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue')

    name_simulation = results[1][0]
    x_values = results[1][1] + 0.98 * time_peakstress
    y_values = results[1][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='steelblue',  linestyle = 'dotted')
    x = [0, 0.98 * time_peakstress] 
    y = [0 , 1]
    plt.plot(x, y, color='steelblue', linestyle = 'dotted')

    name_simulation = results[2][0]
    x_values = results[2][1]
    y_values = results[2][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange')
    
    name_simulation = results[3][0]
    x_values = results[3][1]
    y_values = results[3][2]
    plt.xlim([0, 3e-6])
    plt.plot(x_values, y_values, label=name_simulation, color='darkorange',  linestyle = 'dotted')

    plt.legend()
    if save_plot == True:
        plt.savefig(save_filename + ".svg")
    plt.show()


stress_bar = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, avg_stress_uniform_lip1250[2]/10**6],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, avg_stress_non_uniform_lip1250[2]/10**6],
    ["CZM: 1250el Uniform", time_uniform_czm1250, avg_stress_uniform_czm1250[2]/10**6],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, avg_stress_non_uniform_czm1250[2]/10**6],
]


plotCompareStressCZMLIP_limitime(
    stress_bar,
    title="10to3 1250 elements: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_avg_stress",
)

nfrag = [
    ["LIP: 1250el Uniform", time_uniform_lip1250, n_fragments_uniform_lip1250[2]],
    ["LIP: 1250el Non-Uniform", time_non_uniform_lip1250, n_fragments_non_uniform_lip1250[2]],
    ["CZM: 1250el Uniform", time_uniform_czm1250, n_fragments_uniform_czm1250[2]],
    ["CZM: 1250el Non-Uniform", time_non_uniform_czm1250, n_fragments_non_uniform_czm1250[2]],
]


plotCompareNfragCZMLIP_limitime(
    nfrag,
    title="10to3 1250 elements: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_plot=True,
    save_filename="output_mesh_study/plots_mesh_study/10to3_lip_czm_1250_nfrag",
)

# %%
from matplotlib import pyplot as plt

# meshes = [625, 1250, 2500, 5000, 7500]
meshes = [1250, 2500, 5000, 7500]
lip_nfrag_uniform = [
    # ["625 elements", time_uniform_lip625, n_fragments_uniform_lip625[2]],
    ["1250 elements", time_uniform_lip1250, n_fragments_uniform_lip1250[2]],
    ["2500 elements", time_uniform_lip2500, n_fragments_uniform_lip2500[2]],
    ["5000 elements", time_uniform_lip5000, n_fragments_uniform_lip5000[2]],
    ["7500 elements", time_uniform_lip7500, n_fragments_uniform_lip7500[2]],
]
lip_nfrag_non_uniform = [
    # ["625 elements", time_non_uniform_lip625, n_fragments_non_uniform_lip625[2]],
    ["1250 elements", time_non_uniform_lip1250, n_fragments_non_uniform_lip1250[2]],
    ["2500 elements", time_non_uniform_lip2500, n_fragments_non_uniform_lip2500[2]],
    ["5000 elements", time_non_uniform_lip5000, n_fragments_non_uniform_lip5000[2]],
    ["7500 elements", time_non_uniform_lip7500, n_fragments_non_uniform_lip7500[2]],
]
czm_nfrag_uniform = [
    # ["625 elements", time_uniform_czm625, n_fragments_uniform_czm625[2]],
    ["1250 elements", time_uniform_czm1250, n_fragments_uniform_czm1250[2]],
    ["2500 elements", time_uniform_czm2500, n_fragments_uniform_czm2500[2]],
    ["5000 elements", time_uniform_czm5000, n_fragments_uniform_czm5000[2]],
    ["7500 elements", time_uniform_czm7500, n_fragments_uniform_czm7500[2]],
]
czm_nfrag_non_uniform = [
    # ["625 elements", time_non_uniform_czm625, n_fragments_non_uniform_czm625[2]],
    ["1250 elements", time_non_uniform_czm1250, n_fragments_non_uniform_czm1250[2]],
    ["2500 elements", time_non_uniform_czm2500, n_fragments_non_uniform_czm2500[2]],
    ["5000 elements", time_non_uniform_czm5000, n_fragments_non_uniform_czm5000[2]],
    ["7500 elements", time_non_uniform_czm7500, n_fragments_non_uniform_czm7500[2]],
]

lip_ediss_uniform = [
    # ["625 elements", time_uniform_lip625, energy_diss_uniform_lip625[2]],
    ["1250 elements", time_uniform_lip1250, energy_diss_uniform_lip1250[2]],
    ["2500 elements", time_uniform_lip2500, energy_diss_uniform_lip2500[2]],
    ["5000 elements", time_uniform_lip5000, energy_diss_uniform_lip5000[2]],
    ["7500 elements", time_uniform_lip7500, energy_diss_uniform_lip7500[2]],
]
lip_ediss_non_uniform = [
    # ["625 elements", time_non_uniform_lip625, energy_diss_non_uniform_lip625[2]],
    ["1250 elements", time_non_uniform_lip1250, energy_diss_non_uniform_lip1250[2]],
    ["2500 elements", time_non_uniform_lip2500, energy_diss_non_uniform_lip2500[2]],
    ["5000 elements", time_non_uniform_lip5000, energy_diss_non_uniform_lip5000[2]],
    ["7500 elements", time_non_uniform_lip7500, energy_diss_non_uniform_lip7500[2]],
]
czm_ediss_uniform = [
    # ["625 elements", time_uniform_czm625, energy_diss_uniform_czm625[2]],
    ["1250 elements", time_uniform_czm1250, energy_diss_uniform_czm1250[2]],
    ["2500 elements", time_uniform_czm2500, energy_diss_uniform_czm2500[2]],
    ["5000 elements", time_uniform_czm5000, energy_diss_uniform_czm5000[2]],
    ["7500 elements", time_uniform_czm7500, energy_diss_uniform_czm7500[2]],
]
czm_ediss_non_uniform = [
    # ["625 elements", time_non_uniform_czm625, energy_diss_non_uniform_czm625[2]],
    ["1250 elements", time_non_uniform_czm1250, energy_diss_non_uniform_czm1250[2]],
    ["2500 elements", time_non_uniform_czm2500, energy_diss_non_uniform_czm2500[2]],
    ["5000 elements", time_non_uniform_czm5000, energy_diss_non_uniform_czm5000[2]],
    ["7500 elements", time_non_uniform_czm7500, energy_diss_non_uniform_czm7500[2]],
]






def plotConvergenceCZMLIP(results0, results1, results2, results3,  meshes, title, label_x, label_y, save_filename):

    fig, axes = plt.subplots()
    axes.grid(True, which="both")
    axes.axhline(y=0, color="k")
    plt.title(title)
    plt.xlabel(label_x)
    plt.ylabel(label_y)

    nb_simulations = len(meshes)
    x_values = np.zeros(nb_simulations)
    final_values0 = np.zeros(nb_simulations)
    final_values1 = np.zeros(nb_simulations)
    final_values2 = np.zeros(nb_simulations)
    final_values3 = np.zeros(nb_simulations)

    for i in range(nb_simulations):
        x_values[i] = meshes[i]
        final_values0[i] = max(results0[i][2])
        final_values1[i] = max(results1[i][2])
        final_values2[i] = max(results2[i][2])
        final_values3[i] = max(results3[i][2])
    plt.plot(x_values, final_values0, marker='.',label='LIP: Uniform mesh', color='steelblue')
    plt.plot(x_values, final_values1, marker='.',label="LIP: Non-uniform mesh", color='steelblue', linestyle='dotted')
    plt.plot(x_values, final_values2, marker='.',label="CZM: Uniform mesh", color='darkorange')
    plt.plot(x_values, final_values3, marker='.',label="CZM: Non-uniform mesh", color='darkorange', linestyle='dotted')

    plt.legend()
    plt.savefig(save_filename)
    plt.show()


plotConvergenceCZMLIP(
    lip_nfrag_uniform, 
    lip_nfrag_non_uniform, 
    czm_nfrag_uniform, 
    czm_nfrag_non_uniform, 
    meshes, 
    title="10to3: number fragments convergence", 
    label_x="Number of elements",
    label_y="Number of fragments", 
    save_filename="output_mesh_study/plots_mesh_study/10to3_convergence_nfrag.svg")
plotConvergenceCZMLIP(
    lip_ediss_uniform, 
    lip_ediss_non_uniform, 
    czm_ediss_uniform, 
    czm_ediss_non_uniform, 
    meshes, 
    title="10to3: number fragments convergence", 
    label_x="Number of elements",
    label_y="Dissipated Energy ($ KJ/ {m^2} $)", 
    save_filename="output_mesh_study/plots_mesh_study/10to3_convergence_ediss.svg")
