# %%
import numpy as np

from DFCompare import *

# %% [markdown]
# ## LIP: uniform mesh

# %%
filepath = "LOG/mesh_study/lipfield_uniform_mesh/"

# Uniform mesh 1250 
file_address = filepath + "1250el/backup/lipfield_"
n_fragments_uniform_1250el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_uniform_1250el = readResultsVariable(file_address, "avg_stress_bar")
time_data_uniform_1250el = readResultsVariable(file_address, "time_data")
n_steps_uniform_1250el = time_data_uniform_1250el[2]

# Uniform mesh 2500 
file_address = filepath + "2500el/backup/lipfield_"
n_fragments_uniform_2500el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_uniform_2500el = readResultsVariable(file_address, "avg_stress_bar")
time_data_uniform_2500el = readResultsVariable(file_address, "time_data")
n_steps_uniform_2500el = time_data_uniform_2500el[2]


# Uniform mesh 5000 
file_address = filepath + "5000el/backup/lipfield_"
n_fragments_uniform_5000el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_uniform_5000el = readResultsVariable(file_address, "avg_stress_bar")
time_data_uniform_5000el = readResultsVariable(file_address, "time_data")
n_steps_uniform_5000el = time_data_uniform_5000el[2]


# Uniform mesh 7500 
file_address = filepath + "7500el/backup/lipfield_"
n_fragments_uniform_7500el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_uniform_7500el = readResultsVariable(file_address, "avg_stress_bar")
time_data_uniform_7500el = readResultsVariable(file_address, "time_data")
n_steps_uniform_7500el = time_data_uniform_7500el[2]

# %%
# Separate the results you want to compare
time_simulation = time_data_uniform_1250el[0]

time_uniform_1250el = np.linspace(0, time_simulation, n_steps_uniform_1250el)
time_uniform_2500el = np.linspace(0, time_simulation, n_steps_uniform_2500el)
time_uniform_5000el = np.linspace(0, time_simulation, n_steps_uniform_5000el)
time_uniform_7500el = np.linspace(0, time_simulation, n_steps_uniform_7500el)



stress_bar = [
    ["1250 elements", time_uniform_1250el, avg_stress_bar_uniform_1250el/10**6],
    ["2500 elements", time_uniform_2500el, avg_stress_bar_uniform_2500el/10**6],
    ["5000 elements", time_uniform_5000el, avg_stress_bar_uniform_5000el/10**6],
    ["7500 elements", time_uniform_7500el, avg_stress_bar_uniform_7500el/10**6],
]

plotCompareSimulations(
    stress_bar,
    title="Uniform mesh LIP: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_filename="LOG/mesh_study/plots/lip_uniform_mesh_avg_stress.svg",
)


nfrag_uniform = [
    ["1250 elements", time_uniform_1250el, n_fragments_uniform_1250el],
    ["2500 elements", time_uniform_2500el, n_fragments_uniform_2500el],
    ["5000 elements", time_uniform_5000el, n_fragments_uniform_5000el],
    ["7500 elements", time_uniform_7500el, n_fragments_uniform_7500el],
    # ["7500 elements", time_uniform_7500el, n_fragments_7500el],
]

plotCompareSimulations(
    nfrag_uniform,
    title="Uniform mesh LIP: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/plots/lip_uniform_mesh_n_fragments.svg",
)


# Convergence number fragments
meshes = [1250, 2500, 5000, 7500]

# Convergence dissipated energy
plotConvergence(
    nfrag_uniform,
    meshes, 
    title="Uniform mesh LIP: number fragments convergence",
    label_x="Number of elements",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/plots/lip_uniform_mesh_convergence.svg",
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## LIP: non-uniform mesh

# %%
filepath = "LOG/mesh_study/lipfield_non_uniform_mesh/"

# Uniform mesh 1250 
file_address = filepath + "1250el/backup/lipfield_"
n_fragments_non_uniform_1250el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_non_uniform_1250el = readResultsVariable(file_address, "avg_stress_bar")
time_data_non_uniform_1250el = readResultsVariable(file_address, "time_data")
n_steps_non_uniform_1250el = time_data_non_uniform_1250el[2]

# non_Uniform mesh 2500 
file_address = filepath + "2500el/backup3/lipfield_"
n_fragments_non_uniform_2500el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_non_uniform_2500el = readResultsVariable(file_address, "avg_stress_bar")
time_data_non_uniform_2500el = readResultsVariable(file_address, "time_data")
n_steps_non_uniform_2500el = time_data_non_uniform_2500el[2]


# Non-Uniform mesh 5000 
file_address = filepath + "5000el/backup2/lipfield_"
n_fragments_non_uniform_5000el = readResultsVariable(file_address, "n_fragments")
avg_stress_bar_non_uniform_5000el = readResultsVariable(file_address, "avg_stress_bar")
time_data_non_uniform_5000el = readResultsVariable(file_address, "time_data")
n_steps_non_uniform_5000el = time_data_non_uniform_5000el[2]



# Non-Uniform mesh 7500
file_address = filepath + "7500el/lipfield_"
time_data_non_uniform_7500el = readResultsVariable(file_address, "time_data")
time_simulation_non_uniform_7500el = time_data_non_uniform_7500el[0]
n_steps_non_uniform_7500el = time_data_non_uniform_7500el[2]
size = int(n_steps_non_uniform_7500el / 10)
n_fragments_non_uniform_7500el = np.zeros(size)
avg_stress_bar_non_uniform_7500el = np.zeros(size)
i = 0
for n in range(n_steps_non_uniform_7500el):
    # results_non_uniform_7500el = readPreviousResults(file_address + "step_" + str(n) +"_.pickle")
    if n%10 ==0:
        results_non_uniform_7500el = readPreviousResults(file_address + "step_" + str(n) +"_.pickle")
        n_fragments_non_uniform_7500el[i] = getResults(results_non_uniform_7500el, "n_fragments")
        avg_stress_bar_non_uniform_7500el[i] = getResults(results_non_uniform_7500el, "avg_stress_bar")
        i += 1

# %%
# Separate the results you want to compare
time_simulation = time_data_non_uniform_1250el[0]

time_non_uniform_1250el = np.linspace(0, time_simulation, n_steps_non_uniform_1250el)
time_non_uniform_2500el = np.linspace(0, time_simulation, n_steps_non_uniform_2500el)
time_non_uniform_5000el = np.linspace(0, time_simulation, n_steps_non_uniform_5000el)
time_non_uniform_7500el = np.linspace(0, time_simulation_non_uniform_7500el, size)



stress_bar = [
    ["1250 elements", time_non_uniform_1250el, avg_stress_bar_non_uniform_1250el/10**6],
    ["2500 elements", time_non_uniform_2500el, avg_stress_bar_non_uniform_2500el/10**6],
    ["5000 elements", time_non_uniform_5000el, avg_stress_bar_non_uniform_5000el/10**6],
    ["7500 elements", time_non_uniform_7500el, avg_stress_bar_non_uniform_7500el/10**6],
]

plotCompareSimulations(
    stress_bar,
    title="Non-Uniform mesh LIP: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar (MPa)",
    save_filename="LOG/mesh_study/plots/lip_non_uniform_mesh_avg_stress.svg",
)


nfrag_uniform = [
    ["1250 elements", time_non_uniform_1250el, n_fragments_non_uniform_1250el],
    ["2500 elements", time_non_uniform_2500el, n_fragments_non_uniform_2500el],
    ["5000 elements", time_non_uniform_5000el, n_fragments_non_uniform_5000el],
    ["7500 elements", time_non_uniform_7500el, n_fragments_non_uniform_7500el],
]

plotCompareSimulations(
    nfrag_uniform,
    title="Non-Uniform mesh LIP: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/plots/lip_non_uniform_mesh_n_fragments.svg",
)


# Convergence number fragments
meshes = [1250, 2500, 5000, 7500]

# Convergence dissipated energy
plotConvergence(
    nfrag_uniform,
    meshes, 
    title="Non-Uniform mesh LIP: number fragments convergence",
    label_x="Number of elements",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/plots/lip_non_uniform_mesh_convergence.svg",
)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## LIP: Uniform x Non-Uniform mesh

# %%
filepath = "LOG/mesh_study/lipfield_uniform_mesh/"

file_address = filepath + "1250el/lipfield_"
d_1250el_un = readResults(file_address, "d")
n_fragments_1250el_un = readResults(file_address, "n_fragments")
avg_frag_size_1250el_un = readResults(file_address, "avg_frag_size")
avg_stress_bar_1250el_un = readResults(file_address, "avg_stress_bar")
time_data_1250el_un = readResults(file_address, "time_data")
n_steps_1250el_un = time_data_1250el_un[2]


file_address = filepath + "2500el/lipfield_"
u_2500el_un = readResults(file_address, "u")
v_2500el_un = readResults(file_address, "v")
acel_2500el_un =readResults(file_address, "acel")
d_2500el_un = readResults(file_address, "d")
n_fragments_2500el_un = readResults(file_address, "n_fragments")
avg_frag_size_2500el_un = readResults(file_address, "avg_frag_size")
avg_stress_bar_2500el_un = readResults(file_address, "avg_stress_bar")
energies_2500el_un = readResults(file_address, "energies")
u_all_steps_2500el_un = readResults(file_address, "u_all_steps")
damage_all_steps_2500el_un = readResults(file_address, "damage_all_steps")
stress_all_steps_2500el_un = readResults(file_address, "stress_all_steps")
fraglen_all_steps_2500el_un = readResults(file_address, "fraglen_all_steps")
time_data_2500el_un = readResults(file_address, "time_data")
n_steps_2500el_un = time_data_2500el_un[2]
time_simulation_un = time_data_2500el_un[0]

filepath = "LOG/mesh_study/lipfield_non_uniform_mesh/"

file_address = filepath + "1250el/lipfield_"
d_1250el_nun = readResults(file_address, "d")
n_fragments_1250el_nun = readResults(file_address, "n_fragments")
avg_frag_size_1250el_nun = readResults(file_address, "avg_frag_size")
avg_stress_bar_1250el_nun = readResults(file_address, "avg_stress_bar")
time_data_1250el_nun = readResults(file_address, "time_data")
n_steps_1250el_nun = time_data_1250el_nun[2]


file_address = filepath + "2500el/lipfield_"
u_2500el_nun = readResults(file_address, "u")
v_2500el_nun = readResults(file_address, "v")
acel_2500el_nun =readResults(file_address, "acel")
d_2500el_nun = readResults(file_address, "d")
n_fragments_2500el_nun = readResults(file_address, "n_fragments")
avg_frag_size_2500el_nun = readResults(file_address, "avg_frag_size")
avg_stress_bar_2500el_nun = readResults(file_address, "avg_stress_bar")
energies_2500el_nun = readResults(file_address, "energies")
u_all_steps_2500el_nun = readResults(file_address, "u_all_steps")
damage_all_steps_2500el_nun = readResults(file_address, "damage_all_steps")
stress_all_steps_2500el_nun = readResults(file_address, "stress_all_steps")
fraglen_all_steps_2500el_nun = readResults(file_address, "fraglen_all_steps")
time_data_2500el_nun = readResults(file_address, "time_data")
n_steps_2500el_nun = time_data_2500el_nun[2]
time_simulation = time_data_2500el[0]

# %%
# Separate the results you want to compare

time_1250el_un = np.linspace(0, time_simulation, n_steps_1250el_un)
time_2500el_un = np.linspace(0, time_simulation, n_steps_2500el_un)
time_1250el_nun = np.linspace(0, time_simulation, n_steps_1250el_nun)
time_2500el_nun = np.linspace(0, time_simulation, n_steps_2500el_nun)



stress_bar = [
    ["1250el Uniform", time_1250el_un, avg_stress_bar_1250el_un],
    ["1250el Non-Uniform", time_1250el_nun, avg_stress_bar_1250el_nun],
]

plotCompareSimulations(
    stress_bar,
    title="Uniform x Non-Uniform 1250el mesh LIP: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar",
    save_filename="LOG/mesh_study/avg_stress_1250el.svg",
)

stress_bar = [
    ["2500el Uniform", time_2500el_un, avg_stress_bar_2500el_un],
    ["2500el Non-Uniform", time_2500el_nun, avg_stress_bar_2500el_nun],
]

plotCompareSimulations(
    stress_bar,
    title="Uniform x Non-Uniform 2500el mesh LIP: Average stress",
    label_x="time (s)",
    label_y="Average stress at the bar",
    save_filename="LOG/mesh_study/avg_stress_2500.svg",
)


nfrag = [
    ["1250el Uniform", time_1250el_un,n_fragments_1250el_un],
    ["1250el Non-Uniform", time_1250el_nun, n_fragments_1250el_nun],
]

plotCompareSimulations(
    nfrag,
    title="Non-Uniform mesh 1250el LIP: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/number_fragments_1250.svg",
)

nfrag = [
    ["2500el Uniform", time_2500el_un,n_fragments_2500el_un],
    ["2500el Non-Uniform", time_2500el_nun, n_fragments_2500el_nun],
]

plotCompareSimulations(
    nfrag,
    title="Non-Uniform mesh 2500el LIP: Number of fragments",
    label_x="time (s)",
    label_y="Number of fragments",
    save_filename="LOG/mesh_study/number_fragments_2500.svg",
)


# Convergence number fragments
# # meshes = [1250, 2500, 5000, 7500]
# meshes = [1250, 2500]

# # Convergence dissipated energy
# plotConvergence(
#     nfrag,
#     meshes, 
#     title="Non-Uniform mesh LIP: number fragments convergence",
#     label_x="mesh",
#     label_y="Number of fragments",
#     save_filename="LOG/mesh_study/lipfield_non_uniform_mesh/number_fragments_convergence.svg",
# )
